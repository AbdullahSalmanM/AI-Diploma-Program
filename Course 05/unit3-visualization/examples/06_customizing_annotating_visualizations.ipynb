# %% [markdown]
# # Customizing and Annotating Visualizations for Presentations
#
# ## 📚 Learning Objectives
#
# By completing this notebook, you will:
# - Customize visualizations
# - Add annotations
# - Format charts for presentations
# - Use professional styling
# - Export publication-quality plots
#
# ## 🔗 Prerequisites
#
# - ✅ Understanding of data visualization
# - ✅ Matplotlib/Seaborn knowledge
# - ✅ Presentation design basics
#
# ---
#
# ## Official Structure Reference
#
# This notebook covers practical activities from **Course 05, Unit 3**:
# - Customizing and annotating visualizations for presentations
# - **Source:** `DETAILED_UNIT_DESCRIPTIONS.md` - Unit 3 Practical Content
#
# ---
#
# ## Introduction
#
# **Customizing and annotating visualizations** enhances clarity and professionalism, making charts suitable for presentations and publications.

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd_
print("✅ Libraries imported!")
print("\nCustomizing and Annotating Visualizations")
print("=" * 60)

print("\nCustomization:")
print("  - Colors and styles")
print("  - Fonts and sizes")
print("  - Axes labels")
print("  - Titles and legends")
print("  - Grid and background")

print("\nAnnotations:")
print("  - Text labels")
print("  - Arrows")
print("  - Highlights")
print("  - Callouts")
print("  - Annotations")

print("\nPresentation Quality:")
print("  - High resolution")
print("  - Consistent styling")
print("  - Clear labels")
print("  - Professional appearance")

print("\n✅ Customization concepts understood!")

# %% [markdown]
# # Customizing and Annotating Visualizations for Presentations
#
# ## 📚 Learning Objectives
#
# By completing this notebook, you will:
# - Customize visualizations
# - Add annotations
# - Improve presentation quality
# - Use best practices
# - Create publication-ready charts
#
# ## 🔗 Prerequisites
#
# - ✅ Understanding of visualization
# - ✅ Matplotlib/Seaborn knowledge
# - ✅ Design principles
#
# ---
#
# ## Official Structure Reference
#
# This notebook covers practical activities from **Course 05, Unit 3**:
# - Customizing and annotating visualizations for presentations
# - **Source:** `DETAILED_UNIT_DESCRIPTIONS.md` - Unit 3 Practical Content
#
# ---
#
# ## Introduction
#
# **Customizing and annotating visualizations** enhances clarity and presentation quality, making charts more informative and professional for audiences.

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np_
print("✅ Libraries imported!")
print("\nCustomizing and Annotating Visualizations")
print("=" * 60)

print("\nCustomization:")
print("  - Colors and styles")
print("  - Fonts and sizes")
print("  - Axes labels")
print("  - Titles and legends")
print("  - Grid and background")

print("\nAnnotations:")
print("  - Text labels")
print("  - Arrows and callouts")
print("  - Highlighting")
print("  - Annotations")
print("  - Reference lines")

print("\nPresentation Quality:")
print("  - Clear labels")
print("  - Appropriate colors")
print("  - Readable fonts")
print("  - Professional styling")

print("\n✅ Customization concepts understood!")
