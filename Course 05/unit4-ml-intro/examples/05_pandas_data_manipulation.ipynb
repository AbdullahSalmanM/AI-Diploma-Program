# %% [markdown]
# # Working with Data Using Python Libraries (Pandas)
#
# ## 📚 Learning Objectives
#
# By completing this notebook, you will:
# - Work with Pandas DataFrames
# - Manipulate data
# - Filter and transform data
# - Aggregate data
# - Apply Pandas operations
#
# ## 🔗 Prerequisites
#
# - ✅ Understanding of data manipulation
# - ✅ Pandas knowledge
#
# ---
#
# ## Official Structure Reference
#
# This notebook covers practical activities from **Course 05, Unit 4**:
# - Working with data using Python libraries like Pandas
# - **Source:** `DETAILED_UNIT_DESCRIPTIONS.md` - Unit 4 Practical Content
#
# ---
#
# ## Introduction
#
# **Pandas** is a powerful Python library for data manipulation and analysis, providing DataFrame structures and operations for working with structured data.

# %%
import pandas as pd
import numpy as np_
print("✅ Libraries imported!")
print("\nWorking with Pandas")
print("=" * 60)

print("\nDataFrame Operations:")
print("  - Reading data: CSV, Excel, JSON")
print("  - Viewing data: head, tail, info")
print("  - Selecting: loc, iloc")
print("  - Filtering: Boolean indexing")

print("\nData Manipulation:")
print("  - Adding/removing columns")
print("  - Merging DataFrames")
print("  - Grouping and aggregation")
print("  - Pivoting")

print("\nCommon Tasks:")
print("  - Handling missing values")
print("  - Data type conversion")
print("  - Sorting and ranking")
print("  - String operations")

print("\n✅ Pandas concepts understood!")
