# %% [markdown]
# # Implementing ML Models Using Scikit-learn (Regression, Classification)
#
# ## 📚 Learning Objectives
#
# By completing this notebook, you will:
# - Implement regression models with scikit-learn
# - Implement classification models with scikit-learn
# - Train and evaluate models
# - Use scikit-learn API
# - Apply to real datasets
#
# ## 🔗 Prerequisites
#
# - ✅ Understanding of ML concepts
# - ✅ Scikit-learn knowledge
# - ✅ Data preparation knowledge
#
# ---
#
# ## Official Structure Reference
#
# This notebook covers practical activities from **Course 05, Unit 4**:
# - Implementing ML models using Scikit-learn library (regression, classification)
# - **Source:** `DETAILED_UNIT_DESCRIPTIONS.md` - Unit 4 Practical Content
#
# ---
#
# ## Introduction
#
# **Scikit-learn** provides a comprehensive toolkit for implementing machine learning models, including regression and classification algorithms with consistent APIs.

# %%
import numpy as np
import pandas as pd
from sklearn.linear_model import LinearRegression, LogisticRegression
from sklearn.tree import DecisionTreeClassifier, DecisionTreeRegressor
from sklearn.ensemble import RandomForestClassifier, RandomForestRegressor
from sklearn.metrics import accuracy_score, mean_squared_error, classification_report_
print("✅ Libraries imported!")
print("\nImplementing ML Models with Scikit-learn")
print("=" * 60)

print("\nRegression Models:")
print("  - Linear Regression")
print("  - Decision Tree Regression")
print("  - Random Forest Regression")
print("  - Ridge, Lasso")

print("\nClassification Models:")
print("  - Logistic Regression")
print("  - Decision Tree Classifier")
print("  - Random Forest Classifier")
print("  - SVM, KNN")

print("\nScikit-learn Workflow:")
print("  1. Import model")
print("  2. Create instance")
print("  3. Fit on training data")
print("  4. Predict on test data")
print("  5. Evaluate performance")

print("\n✅ Scikit-learn ML models concepts understood!")

# %% [markdown]
# # Implementing ML Models Using Scikit-learn (Regression, Classification)
#
# ## 📚 Learning Objectives
#
# By completing this notebook, you will:
# - Implement regression models with scikit-learn
# - Implement classification models with scikit-learn
# - Train and evaluate models
# - Use scikit-learn API
# - Apply to real datasets
#
# ## 🔗 Prerequisites
#
# - ✅ Understanding of ML concepts
# - ✅ Scikit-learn knowledge
# - ✅ Data preparation knowledge
#
# ---
#
# ## Official Structure Reference
#
# This notebook covers practical activities from **Course 05, Unit 4**:
# - Implementing ML models using Scikit-learn library (regression, classification)
# - **Source:** `DETAILED_UNIT_DESCRIPTIONS.md` - Unit 4 Practical Content
#
# ---
#
# ## Introduction
#
# **Scikit-learn** provides a unified API for implementing machine learning models, including regression and classification algorithms.

# %%
import numpy as np
import pandas as pd
from sklearn.linear_model import LinearRegression, LogisticRegression
from sklearn.tree import DecisionTreeClassifier, DecisionTreeRegressor
from sklearn.ensemble import RandomForestClassifier, RandomForestRegressor
from sklearn.metrics import accuracy_score, mean_squared_error_
print("✅ Libraries imported!")
print("\nImplementing ML Models with Scikit-learn")
print("=" * 60)

print("\nRegression Models:")
print("  - Linear Regression")
print("  - Decision Tree Regression")
print("  - Random Forest Regression")
print("  - Ridge, Lasso")

print("\nClassification Models:")
print("  - Logistic Regression")
print("  - Decision Tree Classifier")
print("  - Random Forest Classifier")
print("  - SVM, KNN")

print("\nScikit-learn Workflow:")
print("  1. Import model")
print("  2. Create instance")
print("  3. Fit on training data")
print("  4. Predict on test data")
print("  5. Evaluate performance")

print("\n✅ Scikit-learn ML models concepts understood!")
